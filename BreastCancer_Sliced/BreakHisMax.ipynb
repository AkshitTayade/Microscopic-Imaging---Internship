# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
# import cv2
import numpy
import shutil
import os
# import cv2

# %%
# os.listdr("/content/drive/MyDrive/Internships/AI_Medical_Imaging/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/histology_slides/breast/malignant/SOB/ductal_carcinoma")
dest_path = "/content/drive/MyDrive/Internships/AI_Medical_Imaging/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X/benign"
dc = "/content/drive/MyDrive/Internships/AI_Medical_Imaging/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/histology_slides/breast/benign/SOB/tubular_adenoma/"

# os.remove("/content/drive/MyDrive/Internships/AI_Medical_Imaging/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/histology_slides/breast/benign/SOB/adenosis/.DS_Store")
for i in os.listdir(dc):
    # os.remove(f"{dc}.DS_Store")

    for j in os.listdir(f"{dc}{i}"):
        # print(j)
        if j == "200X":
            images = os.listdir(f"{dc}{i}/{j}")
            # print(images)
            for k in images:
                shutil.copy(f"{dc}{i}/{j}/{k}", dest_path)

# %%
# %cd /content/drive/MyDrive/Ninad_Sir_Internship_KJSCE/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X
# Out:
# /content/drive/.shortcut-targets-by-id/1tqHU9PGorczp1G5z9SGO-aWqQGofcNTk/BreaKHis_v1/All_200X

# %%
# !cd "/content/drive/MyDrive/Ninad_Sir_Internship_KJSCE/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X/val/benign"

# %%
base1 = "/content/drive/MyDrive/Ninad_Sir_Internship_KJSCE/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X/val/malignant/"

# %%
images = os.listdir(base1)

# %%
for i in images:
  if i != "fullsized":
    shutil.move(f'{base1}{i}',"/content/drive/MyDrive/Ninad_Sir_Internship_KJSCE/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X/val/malignant/fullsized")
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-87-f5c43653b7f3> in <module>()
#       1 for i in images:
#       2   if i != "fullsized":
# ----> 3     shutil.move(f'{base1}{i}',"/content/drive/MyDrive/Ninad_Sir_Internship_KJSCE/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X/val/malignant/fullsized")
#
# /usr/lib/python3.7/shutil.py in move(src, dst, copy_function)
#     562         real_dst = os.path.join(dst, _basename(src))
#     563         if os.path.exists(real_dst):
# --> 564             raise Error("Destination path '%s' already exists" % real_dst)
#     565     try:
#     566         os.rename(src, real_dst)
#
# ...

# %%
len(os.listdir('/content/drive/MyDrive/Ninad_Sir_Internship_KJSCE/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X/val/malignant/fullsized'))
# Out:
# 209

# %%
src = '/content/drive/MyDrive/Ninad_Sir_Internship_KJSCE/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X/val/malignant/fullsized/'
dest = '/content/drive/MyDrive/Ninad_Sir_Internship_KJSCE/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X/val/malignant/'

# %%
for i in os.listdir(src):
  name = i.split('.')[0]
  os.mkdir(f'{dest}{name}')

  imageSlices = slicer(f'{src}{i}')

  for image in range(9):
    cv2.imwrite(f'{dest}{name}/{name}-{image}.png',imageSlices[image]*255)

# %%
def slicer(imagePath):
  img = plt.imread(imagePath)
  h, w = img.shape[:2]
  ls = []
  for i in range(3):
      roi3 = img[:, int(w*i/3): int(w/3) + int(w*i/3)]
      # plt.imshow(roi)
      for j in range(3):
          roi9 = roi3[int(h*j/3): int(h/3) + int(h*j/3), :]
          ls.append(roi9)
  return ls

# %%
shutil.move('/content/drive/MyDrive/Ninad_Sir_Internship_KJSCE/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X/val/malignant/fullsized','/content/drive/MyDrive/Ninad_Sir_Internship_KJSCE/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X/val')
# Out:
# '/content/drive/MyDrive/Ninad_Sir_Internship_KJSCE/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X/val/fullsized'

# %%
class dataPreProccesing:
    def __init__(self, imagePath, src):
        self.imagePath = imagePath

# %%
base = "/content/drive/MyDrive/Internships/AI_Medical_Imaging/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X/test/benign/"
dest = "/content/drive/MyDrive/Internships/AI_Medical_Imaging/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X/test/benign/fullsized"

for i in os.listdir(base):
    if i != "fullsized":
        shutil.move(f'{base}{i}', dest)

# %%
src = '/content/drive/MyDrive/Ninad_Sir_Internship_KJSCE/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X/test/benign/fullsized/'
dest = '/content/drive/MyDrive/Ninad_Sir_Internship_KJSCE/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X/test/benign/'

# %%
for i in os.listdir(src):
  name = i.split('.')[0]
  os.mkdir(f'{dest}{name}')

  imageSlices = slicer(f'{src}{i}')

  for image in range(9):
    cv2.imwrite(f'{dest}{name}/{name}-{image}.png',imageSlices[image]*255)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-15-8141052c4be1> in <module>()
#       1 for i in os.listdir(src):
#       2   name = i.split('.')[0]
# ----> 3   os.mkdir(f'{dest}{name}')
#       4
#       5   imageSlices = slicer(f'{src}{i}')
#
# FileExistsError: [Errno 17] File exists: '/content/drive/MyDrive/Ninad_Sir_Internship_KJSCE/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X/test/benign/'

# %%
# !zip -r /content/drive/MyDrive/Ninad_Sir_Internship_KJSCE/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X.zip /content/drive/MyDrive/Ninad_Sir_Internship_KJSCE/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/drive/MyDrive/Ninad_Sir_Internship_KJSCE/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X/test/malignant/SOB_M_LC-14-15570C-200-026/SOB_M_LC-14-15570C-200-026-6.png (deflated 1%)
#   adding: content/drive/MyDrive/Ninad_Sir_Internship_KJSCE/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X/test/malignant/SOB_M_LC-14-15570C-200-026/SOB_M_LC-14-15570C-200-026-7.png (deflated 0%)
#   adding: content/drive/MyDrive/Ninad_Sir_Internship_KJSCE/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X/test/malignant/SOB_M_LC-14-15570C-200-026/SOB_M_LC-14-15570C-200-026-8.png (deflated 0%)
#   adding: content/drive/MyDrive/Ninad_Sir_Internship_KJSCE/Microscopic_Images_Internship/Breast_Cancer/Datasets/BreaKHis_v1/All_200X/test/malignant/SOB_M_LC-14-15570C-200-029/ (stored 0%)
# ...

# %%
import os
import cv2
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Flatten, Dense, MaxPooling2D, BatchNormalization, Dropout, Conv2D
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.callbacks import EarlyStopping
from keras.models import load_model
from tensorflow import keras
from keras.layers import Input, Flatten

# %%
class dataCreator:
    def __init__(self,basePath,subPath) -> None:
        self.basePath = basePath
        self.subPath = subPath
        self.subset = []
        print(self.basePath,self.subPath)

    def listAppend(self):
        classes = os.listdir(self.basePath+self.subPath)
        print(classes)

        classCounter = 0

        for i in classes:
            imagePaths = os.listdir(self.basePath+self.subPath+f'/{i}')
            temp = []
            for image in imagePaths:
                temp.append([f"{classCounter}",self.basePath+self.subPath+f'/{i}'+f'/{image}'])
                # print(image)
            classCounter+=1
            self.subset += temp
    
    def shuffler(self):
        np.random.seed(0)
        npsubSet = np.array(self.subset)
        np.random.shuffle(npsubSet)
        return npsubSet

# %%
os.remove('All_200X/test/.DS_Store')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/4m/_7y4kbtd0l5gjj3fhdysn97c0000gn/T/ipykernel_6029/1325377287.py in <module>
# ----> 1 os.remove('All_200X/test/.DS_Store')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'All_200X/test/.DS_Store'

# %%
datagen = dataCreator('All_200X','/test')
datagen.listAppend()
valData = datagen.shuffler()
# Out:
# All_200X /test
# ['malignant', 'benign']

# %%
valData
# Out:
# array([['0', 'All_200X/test/malignant/SOB_M_LC-14-12204-200-041'],
#        ['1', 'All_200X/test/benign/SOB_B_F-14-21998CD-200-018'],
#        ['1', 'All_200X/test/benign/SOB_B_F-14-14134E-200-018'],
#        ['0', 'All_200X/test/malignant/SOB_M_LC-14-15570C-200-018'],
#        ['0', 'All_200X/test/malignant/SOB_M_LC-14-13412-200-010'],
#        ['0', 'All_200X/test/malignant/SOB_M_DC-14-2523-200-029'],
#        ['1', 'All_200X/test/benign/SOB_B_F-14-23222AB-200-003'],
#        ['0', 'All_200X/test/malignant/SOB_M_MC-14-19979C-200-010'],
#        ['0', 'All_200X/test/malignant/SOB_M_DC-14-16188-200-018'],
#        ['0', 'All_200X/test/malignant/SOB_M_LC-14-15570-200-011'],
#        ['1', 'All_200X/test/benign/SOB_B_F-14-14134E-200-005'],
#        ['0', 'All_200X/test/malignant/SOB_M_DC-14-16336-200-002'],
#        ['1', 'All_200X/test/benign/SOB_B_A-14-22549G-200-009'],
#        ['0', 'All_200X/test/malignant/SOB_M_DC-14-14946-200-028'],
# ...

# %%
for i in valData:
    if len(i[1].split(".")) > 1:
        print(i)
# Out:
# ['1' 'All_200X/test/benign/.DS_Store']
# ['0' 'All_200X/test/malignant/.DS_Store']

# %%
import json

# %%
class FeatureExtractor:
    def __init__(self,dataset) -> None:
        self.base_model = tf.keras.applications.VGG19(input_shape=(150,150,3),
                                               include_top=False,
                                               weights='imagenet')
        # print(dataset)
        self.dataset = dataset       
        self.extractedFeatures = []    
        self.labels = []                                 
                                                       
    def preProcessor(self,path):
        img = cv2.imread(path)
        # print(path)
        img = cv2.resize(img,(150,150))
        imgx = np.expand_dims(img, axis=0)
        return imgx                                        
    
    def featureExtractor(self,path):
        feature = self.base_model(self.preProcessor(path))
        flattened = Flatten()(feature)
        # print(feature.shape,flattened.shape)
        return flattened

    def writetoJson(self,path,imagePaths):

        featureList = []

        for i in self.extractedFeatures:
            featureList.append(i.tolist())
        

        dictionary ={ 
        "classes": self.labels, 
        "paths": imagePaths,
        "features": featureList
        } 
            
        # Serializing json  
        json_object = json.dumps(dictionary) 


        # print(path)

        with open(f"{path}/metadata.json", "w") as outfile:
            json.dump(dictionary, outfile)

    def featureArrayCreator(self):
        counter = 0
        
        # if counter <= 0:
        for imgdir in self.dataset:
            # imgdir = self.dataset[k]
            self.labels = []
            self.extractedFeatures = []
            # print(imgdir)
            imageSlicedPaths = []            

            if len(imgdir[1].split('.')) <= 1:

                for i in os.listdir(imgdir[1]):
                    i = str(i, "utf-8")
                    
                    # print(i.decode("utf-8"))

                    if i.split(".")[1]=="png":
                        feature = self.featureExtractor(f'{imgdir[1]}/{i}')
                        self.extractedFeatures.append(feature.numpy())
                        self.labels.append(int(imgdir[0]))  
                        imageSlicedPaths.append(f'{imgdir[1]}/{i}')
                        # counter +=1
                print(counter/len(self.dataset)*100/9)
                # print(self.labels,self.extractedFeatures)
                self.writetoJson(imgdir[1],imageSlicedPaths)
                counter+=1
          
        # return [np.array(self.labels),np.array(self.extractedFeatures)]

# %%
featureCreator = FeatureExtractor(valData)
featureCreator.featureArrayCreator()
# Out:
# 0.0
# 0.036192544335866814
# 0.07238508867173363
# 0.10857763300760043
# 0.14477017734346725
# 0.18096272167933405
# 0.21715526601520085
# 0.2533478103510677
# 0.2895403546869345
# 0.3257328990228013
# 0.3619254433586681
# 0.39811798769453494
# 0.4343105320304017
# 0.47050307636626854
# 0.5066956207021354
# 0.5428881650380022
# 0.579080709373869
# 0.6152732537097357
# 0.6514657980456026
# 0.6876583423814694
# 0.7238508867173362
# 0.760043431053203
# 0.7962359753890699
# 0.8324285197249367
# 0.8686210640608034
# 0.9048136083966702
# 0.9410061527325371
# 0.9771986970684039
# 1.0133912414042707
# 1.0495837857401376
# 1.0857763300760044
# 1.1219688744118712
# 1.158161418747738
# 1.1943539630836049
# 1.2305465074194715
# 1.2667390517553383
# 1.3029315960912051
# 1.339124140427072
# 1.3753166847629388
# 1.4115092290988056
# 1.4477017734346724
# 1.4838943177705393
# 1.520086862106406
# 1.556279406442273
# 1.5924719507781397
# 1.6286644951140066
# 1.6648570394498734
# 1.7010495837857402
# ...

# %%
print(Xtrain)
# Out:
# []
